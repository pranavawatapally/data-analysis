# %%
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format
pd.options.mode.chained_assignment = None

# %%
df = pd.read_excel(r'C:\Users\AV KALI PRANAV\Desktop\Data Analysis Proof\IPL Dataset 2021\ipl_2021_dataset.xlsx', sheet_name='ipl_2021_dataset')

# %%
df
# Out:
#      Unnamed: 0                  Player  Base Price         TYPE  \
# 0             0             Rashid Khan  Draft Pick       BOWLER
# 1             1           Hardik Pandya  Draft Pick  ALL-ROUNDER
# 2             2         Lockie Ferguson        2 Cr       BOWLER
# 3             3           Rahul Tewatia     40 Lakh  ALL-ROUNDER
# 4             4            Shubman Gill  Draft Pick       BATTER
# ..          ...                     ...         ...          ...
# 628         628            Sairaj Patil     20 Lakh       BATTER
# 629         629              Monu Singh     20 Lakh       BOWLER
# 630         630  Nivethan Radhakrishnan     20 Lakh       BOWLER
# 631         631            Lance Morris     20 Lakh       BOWLER
# 632         632            Aaron Hardie     20 Lakh  ALL-ROUNDER
#
#      COST IN â‚¹ (CR.)  Cost IN $ (000) 2021 Squad            Team
# 0                15.00          1950.00        SRH  Gujarat Titans
# ...

# %%
"""
objectives: 
1) change the first column name to jersey number
2) seperate list of unsold players from data
3) remove rows with empty data
4) adding columns called cost_INR_full and cost_USD_full with all digits
5) delete the columns [cost_INR] [cost_USD]
6) create new column [cost_AUD]
7) top 10 players from csk based on price
8) jersey numbers of the top 10 players based on the auction price
9) list all allrounders from type
10) players list based and their SQAD
11) replace the jersey number for "dhoni" in csk team.
12) Display entire details of a particular player based on the row index
"""
# Out:
# '\nobjectives: \n1) change the first column name to jersey number\n2) seperate list of unsold players from data\n3) remove rows with empty data\n4) adding columns called cost_INR_full and cost_USD_full with all digits\n5) delete the columns [cost_INR] [cost_USD]\n6) create new column [cost_AUD]\n7) top 10 players from csk based on price\n8) jersey numbers of the top 10 players based on the auction price\n9) list all allrounders from type\n10) players list based and their SQAD\n'

# %%
df = df.rename(columns={'Unnamed: 0': 'jersey_number', 'Base Price': 'base_price', 'COST IN â‚¹ (CR.)': 'cost_INR', 'Cost IN $ (000)': 'cost_USD', '2021 Squad': '2021_squad'  })
df_backup = df.copy()

# %%
df_backup
# Out:
#      jersey_number                  Player  base_price         TYPE  cost_INR  \
# 0                0             Rashid Khan  Draft Pick       BOWLER     15.00
# 1                1           Hardik Pandya  Draft Pick  ALL-ROUNDER     15.00
# 2                2         Lockie Ferguson        2 Cr       BOWLER     10.00
# 3                3           Rahul Tewatia     40 Lakh  ALL-ROUNDER      9.00
# 4                4            Shubman Gill  Draft Pick       BATTER      8.00
# ..             ...                     ...         ...          ...       ...
# 628            628            Sairaj Patil     20 Lakh       BATTER       NaN
# 629            629              Monu Singh     20 Lakh       BOWLER       NaN
# 630            630  Nivethan Radhakrishnan     20 Lakh       BOWLER       NaN
# 631            631            Lance Morris     20 Lakh       BOWLER       NaN
# 632            632            Aaron Hardie     20 Lakh  ALL-ROUNDER       NaN
#
# ...

# %%
# here we have removed the NAN values from the table by assigning it to the new variable so that the actual data remains same
df_no_nan = df.dropna()

# %%
df_no_nan
# Out:
#      jersey_number              Player  base_price          TYPE  cost_INR  \
# 0                0         Rashid Khan  Draft Pick        BOWLER     15.00
# 1                1       Hardik Pandya  Draft Pick   ALL-ROUNDER     15.00
# 2                2     Lockie Ferguson        2 Cr        BOWLER     10.00
# 3                3       Rahul Tewatia     40 Lakh   ALL-ROUNDER      9.00
# 4                4        Shubman Gill  Draft Pick        BATTER      8.00
# ..             ...                 ...         ...           ...       ...
# 228            228      Glenn Phillips      1.5 Cr  WICKETKEEPER      1.50
# 229            229       Shreyas Gopal     20 Lakh        BOWLER      0.75
# 230            230        Vishnu Vinod     20 Lakh  WICKETKEEPER      0.50
# 232            232         Priyam Garg     20 Lakh        BATTER      0.20
# 234            234  Jagadeesha Suchith     20 Lakh        BOWLER      0.20
#
#      cost_USD 2021_squad                 Team
# ...

# %%
#this is how you get the single row from the set of rows
df[df["Player"] =="Rashid Khan"]
# Out:
#    jersey_number       Player  base_price    TYPE  cost_INR  cost_USD  \
# 0              0  Rashid Khan  Draft Pick  BOWLER     15.00   1950.00
#
#   2021_squad            Team
# 0        SRH  Gujarat Titans

# %%
# here we are passing multiple arguments to get the all rounder players from the KKR squad whose team is Kolkata Knight Riders
df[(df["2021_squad"]=="KKR") & (df["jersey_number"]>75) & (df["Team"]!="Unsold") & (df["Team"]=="Kolkata Knight Riders")]
# Out:
#     jersey_number           Player base_price          TYPE  cost_INR  \
# 76             76      Pat Cummins       2 Cr   ALL-ROUNDER      7.25
# 77             77      Shivam Mavi    40 Lakh   ALL-ROUNDER      7.25
# 78             78     Sunil Narine   Retained   ALL-ROUNDER      6.00
# 81             81      Tim Southee     1.5 Cr        BOWLER      1.50
# 85             85  Sheldon Jackson    30 Lakh  WICKETKEEPER      0.60
#
#     cost_USD 2021_squad                   Team
# 76    942.50        KKR  Kolkata Knight Riders
# 77    942.50        KKR  Kolkata Knight Riders
# 78    780.00        KKR  Kolkata Knight Riders
# 81    195.00        KKR  Kolkata Knight Riders
# 85     78.00        KKR  Kolkata Knight Riders

# %%
unsold = df[df["Team"]=="Unsold"]
unsold
# Out:
#      jersey_number                  Player base_price         TYPE  cost_INR  \
# 237            237            Suresh Raina       2 Cr       BATTER       NaN
# 238            238             Steve Smith       2 Cr       BATTER       NaN
# 239            239         Shakib Al Hasan       2 Cr  ALL-ROUNDER       NaN
# 240            240             Amit Mishra     1.5 Cr       BOWLER       NaN
# 241            241             Adil Rashid       2 Cr       BOWLER       NaN
# ..             ...                     ...        ...          ...       ...
# 628            628            Sairaj Patil    20 Lakh       BATTER       NaN
# 629            629              Monu Singh    20 Lakh       BOWLER       NaN
# 630            630  Nivethan Radhakrishnan    20 Lakh       BOWLER       NaN
# 631            631            Lance Morris    20 Lakh       BOWLER       NaN
# 632            632            Aaron Hardie    20 Lakh  ALL-ROUNDER       NaN
#
#      cost_USD 2021_squad    Team
# ...

# %%
conv = df['cost_INR'] * 10000000

# %%
conv
# Out:
# 0     150000000.00
# 1     150000000.00
# 2     100000000.00
# 3      90000000.00
# 4      80000000.00
#           ...
# 628            NaN
# 629            NaN
# 630            NaN
# 631            NaN
# 632            NaN
# Name: cost_INR, Length: 633, dtype: float64

# %%
df
# Out:
#      jersey_number                  Player  base_price         TYPE  cost_INR  \
# 0                0             Rashid Khan  Draft Pick       BOWLER     15.00
# 1                1           Hardik Pandya  Draft Pick  ALL-ROUNDER     15.00
# 2                2         Lockie Ferguson        2 Cr       BOWLER     10.00
# 3                3           Rahul Tewatia     40 Lakh  ALL-ROUNDER      9.00
# 4                4            Shubman Gill  Draft Pick       BATTER      8.00
# ..             ...                     ...         ...          ...       ...
# 628            628            Sairaj Patil     20 Lakh       BATTER       NaN
# 629            629              Monu Singh     20 Lakh       BOWLER       NaN
# 630            630  Nivethan Radhakrishnan     20 Lakh       BOWLER       NaN
# 631            631            Lance Morris     20 Lakh       BOWLER       NaN
# 632            632            Aaron Hardie     20 Lakh  ALL-ROUNDER       NaN
#
# ...

# %%
 df['cost_INR'] * 10000000
# Out:
# 0     150000000.00
# 1     150000000.00
# 2     100000000.00
# 3      90000000.00
# 4      80000000.00
#           ...
# 628            NaN
# 629            NaN
# 630            NaN
# 631            NaN
# 632            NaN
# Name: cost_INR, Length: 633, dtype: float64

# %%
#here we are converting the cost_INR to full figures
df['cost_INR'] = df['cost_INR'] * 10000000

# %%
df
# Out:
#      jersey_number                  Player  base_price         TYPE  \
# 0                0             Rashid Khan  Draft Pick       BOWLER
# 1                1           Hardik Pandya  Draft Pick  ALL-ROUNDER
# 2                2         Lockie Ferguson        2 Cr       BOWLER
# 3                3           Rahul Tewatia     40 Lakh  ALL-ROUNDER
# 4                4            Shubman Gill  Draft Pick       BATTER
# ..             ...                     ...         ...          ...
# 628            628            Sairaj Patil     20 Lakh       BATTER
# 629            629              Monu Singh     20 Lakh       BOWLER
# 630            630  Nivethan Radhakrishnan     20 Lakh       BOWLER
# 631            631            Lance Morris     20 Lakh       BOWLER
# 632            632            Aaron Hardie     20 Lakh  ALL-ROUNDER
#
#         cost_INR  cost_USD 2021_squad            Team
# 0   150000000.00   1950.00        SRH  Gujarat Titans
# ...

# %%
df['cost_USD'] = df['cost_USD'] * 1000000

# %%
df
# Out:
#      jersey_number                  Player  base_price         TYPE  \
# 0                0             Rashid Khan  Draft Pick       BOWLER
# 1                1           Hardik Pandya  Draft Pick  ALL-ROUNDER
# 2                2         Lockie Ferguson        2 Cr       BOWLER
# 3                3           Rahul Tewatia     40 Lakh  ALL-ROUNDER
# 4                4            Shubman Gill  Draft Pick       BATTER
# ..             ...                     ...         ...          ...
# 628            628            Sairaj Patil     20 Lakh       BATTER
# 629            629              Monu Singh     20 Lakh       BOWLER
# 630            630  Nivethan Radhakrishnan     20 Lakh       BOWLER
# 631            631            Lance Morris     20 Lakh       BOWLER
# 632            632            Aaron Hardie     20 Lakh  ALL-ROUNDER
#
#         cost_INR      cost_USD 2021_squad            Team
# 0   150000000.00 1950000000.00        SRH  Gujarat Titans
# ...

# %%
# here we are creating the new column
df['cost_USD_test'] = df['cost_USD'] * 1000000

# %%
df
# Out:
#      jersey_number                  Player  base_price         TYPE  \
# 0                0             Rashid Khan  Draft Pick       BOWLER
# 1                1           Hardik Pandya  Draft Pick  ALL-ROUNDER
# 2                2         Lockie Ferguson        2 Cr       BOWLER
# 3                3           Rahul Tewatia     40 Lakh  ALL-ROUNDER
# 4                4            Shubman Gill  Draft Pick       BATTER
# ..             ...                     ...         ...          ...
# 628            628            Sairaj Patil     20 Lakh       BATTER
# 629            629              Monu Singh     20 Lakh       BOWLER
# 630            630  Nivethan Radhakrishnan     20 Lakh       BOWLER
# 631            631            Lance Morris     20 Lakh       BOWLER
# 632            632            Aaron Hardie     20 Lakh  ALL-ROUNDER
#
#         cost_INR      cost_USD 2021_squad            Team       cost_USD_test
# ...

# %%
# delete the column
del df['cost_USD_test']

# %%
df
# Out:
#      jersey_number                  Player  base_price         TYPE  \
# 0                0             Rashid Khan  Draft Pick       BOWLER
# 1                1           Hardik Pandya  Draft Pick  ALL-ROUNDER
# 2                2         Lockie Ferguson        2 Cr       BOWLER
# 3                3           Rahul Tewatia     40 Lakh  ALL-ROUNDER
# 4                4            Shubman Gill  Draft Pick       BATTER
# ..             ...                     ...         ...          ...
# 628            628            Sairaj Patil     20 Lakh       BATTER
# 629            629              Monu Singh     20 Lakh       BOWLER
# 630            630  Nivethan Radhakrishnan     20 Lakh       BOWLER
# 631            631            Lance Morris     20 Lakh       BOWLER
# 632            632            Aaron Hardie     20 Lakh  ALL-ROUNDER
#
#         cost_INR      cost_USD 2021_squad            Team
# 0   150000000.00 1950000000.00        SRH  Gujarat Titans
# ...

# %%
df_no_nan = df.dropna()
df_no_nan
# Out:
#      jersey_number              Player  base_price          TYPE     cost_INR  \
# 0                0         Rashid Khan  Draft Pick        BOWLER 150000000.00
# 1                1       Hardik Pandya  Draft Pick   ALL-ROUNDER 150000000.00
# 2                2     Lockie Ferguson        2 Cr        BOWLER 100000000.00
# 3                3       Rahul Tewatia     40 Lakh   ALL-ROUNDER  90000000.00
# 4                4        Shubman Gill  Draft Pick        BATTER  80000000.00
# ..             ...                 ...         ...           ...          ...
# 228            228      Glenn Phillips      1.5 Cr  WICKETKEEPER  15000000.00
# 229            229       Shreyas Gopal     20 Lakh        BOWLER   7500000.00
# 230            230        Vishnu Vinod     20 Lakh  WICKETKEEPER   5000000.00
# 232            232         Priyam Garg     20 Lakh        BATTER   2000000.00
# 234            234  Jagadeesha Suchith     20 Lakh        BOWLER   2000000.00
#
# ...

# %%
df_no_nan.sort_values(["cost_INR"],ascending=False)
# Out:
#      jersey_number              Player  base_price          TYPE     cost_INR  \
# 121            121            KL Rahul  Draft Pick  WICKETKEEPER 170000000.00
# 22              22     Ravindra Jadeja    Retained   ALL-ROUNDER 160000000.00
# 47              47        Rishabh Pant    Retained  WICKETKEEPER 160000000.00
# 143            143        Rohit Sharma    Retained        BATTER 160000000.00
# 144            144        Ishan Kishan        2 Cr  WICKETKEEPER 152500000.00
# ..             ...                 ...         ...           ...          ...
# 40              40     Simarjeet Singh     20 Lakh        BOWLER   2000000.00
# 39              39     K.Bhagath Varma     20 Lakh   ALL-ROUNDER   2000000.00
# 20              20    Darshan Nalkande     20 Lakh   ALL-ROUNDER   2000000.00
# 232            232         Priyam Garg     20 Lakh        BATTER   2000000.00
# 234            234  Jagadeesha Suchith     20 Lakh        BOWLER   2000000.00
#
# ...

# %%
# here I have listed top 10 players in csk as per their auction price
df_no_nan[(df_no_nan["2021_squad"]=="CSK") & (df_no_nan["Team"]=="Chennai Super Kings")].sort_values(['cost_INR'], ascending=False)
# Out:
#     jersey_number            Player base_price          TYPE     cost_INR  \
# 22             22   Ravindra Jadeja   Retained   ALL-ROUNDER 160000000.00
# 23             23     Deepak Chahar       2 Cr        BOWLER 140000000.00
# 24             24          MS Dhoni   Retained  WICKETKEEPER 120000000.00
# 25             25         Moeen Ali   Retained   ALL-ROUNDER  80000000.00
# 26             26     Ambati Rayudu       2 Cr  WICKETKEEPER  67500000.00
# 27             27   Ruturaj Gaikwad   Retained        BATTER  60000000.00
# 28             28      Dwayne Bravo       2 Cr   ALL-ROUNDER  44000000.00
# 31             31     Robin Uthappa       2 Cr        BATTER  20000000.00
# 32             32  Mitchell Santner       1 Cr   ALL-ROUNDER  19000000.00
# 39             39   K.Bhagath Varma    20 Lakh   ALL-ROUNDER   2000000.00
# 41             41     N. Jagadeesan    20 Lakh  WICKETKEEPER   2000000.00
# 42             42  C.Hari Nishaanth    20 Lakh        BATTER   2000000.00
# ...

# %%
# jersey numbers of the top 10 players based on the auction price
#df_no_nan['cost_INR'].nlargest(n=10)
df_no_nan[['jersey_number', 'cost_INR']].sort_values(['cost_INR'], ascending=False).head(10)
# Out:
#      jersey_number     cost_INR
# 121            121 170000000.00
# 22              22 160000000.00
# 47              47 160000000.00
# 143            143 160000000.00
# 144            144 152500000.00
# 1                1 150000000.00
# 0                0 150000000.00
# 168            168 150000000.00
# 214            214 140000000.00
# 190            190 140000000.00

# %%
#here we have all the allrounders list
df_no_nan[df_no_nan["TYPE"] =="ALL-ROUNDER"]
# Out:
#      jersey_number               Player  base_price         TYPE  cost_INR  \
# 1                1        Hardik Pandya  Draft Pick  ALL-ROUNDER     15.00
# 3                3        Rahul Tewatia     40 Lakh  ALL-ROUNDER      9.00
# 14              14         Jayant Yadav        1 Cr  ALL-ROUNDER      1.70
# 15              15        Vijay Shankar     50 Lakh  ALL-ROUNDER      1.40
# 16              16       Dominic Drakes     75 Lakh  ALL-ROUNDER      1.10
# 18              18      Gurkeerat Singh     50 Lakh  ALL-ROUNDER      0.50
# 20              20     Darshan Nalkande     20 Lakh  ALL-ROUNDER      0.20
# 22              22      Ravindra Jadeja    Retained  ALL-ROUNDER     16.00
# 25              25            Moeen Ali    Retained  ALL-ROUNDER      8.00
# 28              28         Dwayne Bravo        2 Cr  ALL-ROUNDER      4.40
# 29              29          Shivam Dube     50 Lakh  ALL-ROUNDER      4.00
# ...

# %%
#here we are listing all the players based on their Squad
df_no_nan[(df_no_nan["2021_squad"] =="MI") & (df_no_nan["Team"] =="Mumbai Indians")]
# Out:
#      jersey_number            Player base_price          TYPE     cost_INR  \
# 143            143      Rohit Sharma   Retained        BATTER 160000000.00
# 144            144      Ishan Kishan       2 Cr  WICKETKEEPER 152500000.00
# 145            145    Jasprit Bumrah   Retained        BOWLER 120000000.00
# 148            148  Suryakumar Yadav   Retained        BATTER  80000000.00
# 149            149    Kieron Pollard   Retained   ALL-ROUNDER  60000000.00
# 160            160   Arjun Tendulkar    20 Lakh   ALL-ROUNDER   3000000.00
# 162            162  Anmolpreet Singh    20 Lakh        BATTER   2000000.00
#
#          cost_USD 2021_squad            Team
# 143 2080000000.00         MI  Mumbai Indians
# 144 1982500000.00         MI  Mumbai Indians
# 145 1560000000.00         MI  Mumbai Indians
# 148 1040000000.00         MI  Mumbai Indians
# 149  780000000.00         MI  Mumbai Indians
# 160   39000000.00         MI  Mumbai Indians
# 162   26000000.00         MI  Mumbai Indians

# %%
#here we are listing all the players based on their team
df_no_nan[(df_no_nan["Team"] =="Mumbai Indians")].sort_values(['Player'], ascending=True)
# Out:
#      jersey_number            Player base_price          TYPE  cost_INR  \
# 162            162  Anmolpreet Singh    20 Lakh        BATTER      0.20
# 160            160   Arjun Tendulkar    20 Lakh   ALL-ROUNDER      0.30
# 161            161      Basil Thampi    30 Lakh        BOWLER      0.30
# 151            151       Daniel Sams       1 Cr   ALL-ROUNDER      2.60
# 144            144      Ishan Kishan       2 Cr  WICKETKEEPER     15.25
# 145            145    Jasprit Bumrah   Retained        BOWLER     12.00
# 155            155    Jaydev Unadkat    75 Lakh        BOWLER      1.30
# 147            147      Jofra Archer       2 Cr   ALL-ROUNDER      8.00
# 149            149    Kieron Pollard   Retained   ALL-ROUNDER      6.00
# 158            158   Mayank Markande    50 Lakh        BOWLER      0.65
# 153            153    Murugan Ashwin    20 Lakh        BOWLER      1.60
# 156            156    Riley Meredith       1 Cr        BOWLER      1.00
# ...

# %%
#here we have replaced the jersey number of dhoni from 24 to 7
df_no_nan[(df_no_nan["2021_squad"]=="CSK") & (df_no_nan["Team"]=="Chennai Super Kings")].sort_values(['cost_INR'], ascending=False).replace({'base_price':{'MS Dhoni':'MS Anand'}})
# Out:
#     jersey_number            Player base_price          TYPE     cost_INR  \
# 22             22   Ravindra Jadeja   Retained   ALL-ROUNDER 160000000.00
# 23             23     Deepak Chahar       2 Cr        BOWLER 140000000.00
# 24             24          MS Anand   Retained  WICKETKEEPER 120000000.00
# 25             25         Moeen Ali   Retained   ALL-ROUNDER  80000000.00
# 26             26     Ambati Rayudu       2 Cr  WICKETKEEPER  67500000.00
# 27             27   Ruturaj Gaikwad   Retained        BATTER  60000000.00
# 28             28      Dwayne Bravo       2 Cr   ALL-ROUNDER  44000000.00
# 31             31     Robin Uthappa       2 Cr        BATTER  20000000.00
# 32             32  Mitchell Santner       1 Cr   ALL-ROUNDER  19000000.00
# 39             39   K.Bhagath Varma    20 Lakh   ALL-ROUNDER   2000000.00
# 41             41     N. Jagadeesan    20 Lakh  WICKETKEEPER   2000000.00
# 42             42  C.Hari Nishaanth    20 Lakh        BATTER   2000000.00
# ...

# %%
df_no_nan.at[24,'base_price']='20 Cr'
df_no_nan[0:24]
# Out:
#     jersey_number            Player  base_price          TYPE     cost_INR  \
# 0               0       Rashid Khan  Draft Pick        BOWLER 150000000.00
# 1               1     Hardik Pandya  Draft Pick   ALL-ROUNDER 150000000.00
# 2               2   Lockie Ferguson        2 Cr        BOWLER 100000000.00
# 3               3     Rahul Tewatia     40 Lakh   ALL-ROUNDER  90000000.00
# 4               4      Shubman Gill  Draft Pick        BATTER  80000000.00
# 5               5    Mohammad Shami        2 Cr        BOWLER  62500000.00
# 7               7      David Miller        1 Cr        BATTER  30000000.00
# 8               8    R. Sai Kishore     20 Lakh        BOWLER  30000000.00
# 12             12         Jason Roy        2 Cr        BATTER  20000000.00
# 13             13   Wriddhiman Saha        1 Cr  WICKETKEEPER  19000000.00
# 14             14      Jayant Yadav        1 Cr   ALL-ROUNDER  17000000.00
# ...

# %%
df_no_nan.iloc[17,3] = 'CAPTAIN'
df_no_nan[:25]
# Out:
#     jersey_number            Player  base_price          TYPE     cost_INR  \
# 0               0       Rashid Khan  Draft Pick        BOWLER 150000000.00
# 1               1     Hardik Pandya  Draft Pick   ALL-ROUNDER 150000000.00
# 2               2   Lockie Ferguson        2 Cr        BOWLER 100000000.00
# 3               3     Rahul Tewatia     40 Lakh   ALL-ROUNDER  90000000.00
# 4               4      Shubman Gill  Draft Pick        BATTER  80000000.00
# 5               5    Mohammad Shami        2 Cr        BOWLER  62500000.00
# 7               7      David Miller        1 Cr        BATTER  30000000.00
# 8               8    R. Sai Kishore     20 Lakh        BOWLER  30000000.00
# 12             12         Jason Roy        2 Cr        BATTER  20000000.00
# 13             13   Wriddhiman Saha        1 Cr  WICKETKEEPER  19000000.00
# 14             14      Jayant Yadav        1 Cr   ALL-ROUNDER  17000000.00
# ...

# %%
# values between 10 to 20 rows and selected columns
# df.iloc[row_index(compulsory),column_index(optional)]
# range [first_count:last_count]

#here we are getting the entire details of a particular player based on the row index
df_no_nan.iloc[24,:]
# Out:
# jersey_number                     31
# Player                 Robin Uthappa
# base_price                      2 Cr
# TYPE                         CAPTAIN
# cost_INR                 20000000.00
# cost_USD                260000000.00
# 2021_squad                       CSK
# Team             Chennai Super Kings
# Name: 31, dtype: object

# %%
# here we are assigning the iloc values to a variable and using that variable we have changed a value in the desired location
test = df.iloc[10:21,2:6]
test.at[12,'TYPE'] = 'CAPTAIN'
test
# Out:
#    base_price          TYPE    cost_INR     cost_USD
# 10       2 Cr  WICKETKEEPER 24000000.00 312000000.00
# 11    75 Lakh        BOWLER 24000000.00 312000000.00
# 12       2 Cr       CAPTAIN 20000000.00 260000000.00
# 13       1 Cr  WICKETKEEPER 19000000.00 247000000.00
# 14       1 Cr   ALL-ROUNDER 17000000.00 221000000.00
# 15    50 Lakh   ALL-ROUNDER 14000000.00 182000000.00
# 16    75 Lakh   ALL-ROUNDER 11000000.00 143000000.00
# 17    50 Lakh        BOWLER  5000000.00  65000000.00
# 18    50 Lakh   ALL-ROUNDER  5000000.00  65000000.00
# 19    30 Lakh        BOWLER  3000000.00  39000000.00
# 20    20 Lakh   ALL-ROUNDER  2000000.00  26000000.00
